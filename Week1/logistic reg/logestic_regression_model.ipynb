# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.head()

# %%
test.head()

# %%
train = train.drop(columns='Name')
test = test.drop(columns='Name')

# %%
cols = [
    'Age',
    'Fare'
]
train[cols] = train[cols].fillna(train[cols].median())
test[cols] = test[cols].fillna(train[cols].median())

# %%
train['Deck'] = train['Cabin'].str[0]
test['Deck'] = train['Cabin'].str[0]


train['Deck'] = train['Deck'].fillna('U')
test['Deck'] = test['Deck'].fillna('U')

# %%
train['Embarked'] = train['Embarked'].fillna(train['Embarked'].mode()[0])

# %%
train = train.drop(columns='Cabin')
test = test.drop(columns='Cabin')

# %%
train['Sex'] = train['Sex'].map({'male':0, 'female':1})
test['Sex'] = test['Sex'].map({'male':0, 'female':1})

# %%
train = train.drop(columns='Ticket')
test = test.drop(columns='Ticket')

# %%
train = pd.get_dummies(train, columns=['Embarked', 'Deck'], drop_first=True)
test = pd.get_dummies(test, columns=['Embarked', 'Deck'], drop_first=True)

# %%
dummy_cols = [col for col in train.columns if col.startswith('Embarked_') or col.startswith('Deck_')]
train[dummy_cols] = train[dummy_cols].astype(int)
test[dummy_cols] = test[dummy_cols].astype(int)

# %%
train.head()

# %%
test.head()
